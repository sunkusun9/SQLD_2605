# %%
import os
import pandas as pd
from sqlalchemy import create_engine, text
import cx_Oracle
import sys
if sys.version.find('GCC') >= 0:
    DATABASE_URL = "oracle+cx_oracle://lib:multisqld@oracle-db:1521/?service_name=XEPDB1"
else:
    cx_Oracle.init_oracle_client(lib_dir = r"C:\Oracle\instantclient_23_7")
    DATABASE_URL = "oracle+cx_oracle://lib:multisqld@localhost:1521/?service_name=XEPDB1"
engine = create_engine(DATABASE_URL)

def get_rows(qry):
    try:
        with engine.connect() as conn:
            result = conn.execute(text(qry))
            return pd.DataFrame(result.fetchall(), columns = result.keys())
    except Exception as e:
        print(e)
def exec_mq(conn, no, qry, d, interval = 100):
    try:
        result = conn.execute(text(qry), d)
        if no % interval == 0:
            conn.commit()
    except Exception as e:
        print(e)
        return 0
    return 1
	
	
get_rows("SELECT * FROM BookCategory")
# Out:
#       categ_id   categ_name  parent_categ_id            reg_date  use_yn  \
# 0          309        언어학교재            300.0 2019-09-18 10:58:20       1
# 1          310      기타 외국문학            300.0 2019-09-20 12:13:48       1
# 2          312     가정학/소비자학            311.0 2019-09-23 11:34:20       1
# 3          313  국악/성악/음대 교재            311.0 2019-09-23 12:14:33       1
# 4          314    디자인/미술/만화            311.0 2019-09-25 11:19:00       1
# ...        ...          ...              ...                 ...     ...
# 1601      1595        미국교과서           1588.0 2025-02-13 15:14:13       1
# 1602      1601    초등학습법/플래너           1600.0 2025-02-19 13:16:07       1
# 1603      1602   학습교구/퍼즐/게임           1600.0 2025-02-17 12:15:16       1
# 1604      1604      EBS 중학교           1603.0 2025-02-18 11:05:00       1
# 1605      1609     중1 - 문제집           1603.0 2025-02-19 12:51:06       1
#
#       nav_seq
# 0           9
# 1          10
# 2           1
# 3           2
# 4           4
# ...       ...
# 1601        7
# 1602        2
# 1603        1
# 1604        1
# 1605        2
#
# [1606 rows x 6 columns]
